# %% [markdown]
# # Gráficos en python

# %%
# %pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x = [0,2,4,6,8,10]
y = [89,67,45,65,23,67]

plt.plot(x,y)
plt.title('Ventas')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(x,y)
plt.title('Ventas')
plt.xlabel('Día')
plt.ylabel('Número de Ventas')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
experiencia = [1,3,5,7,9]
Salario_data_scientists = [3434,6436,2343,4656,8999]
Salario_ing_Software = [3344,63446,2343,46456,84599]

# %%
plt.plot(experiencia,Salario_data_scientists)
plt.plot(experiencia,Salario_ing_Software)
plt.title('Salarios')
plt.xlabel('Experiencia')
plt.ylabel('Ganacias')
plt.legend(['Data Scientis', 'Ing en Software'])
plt.show
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(experiencia,Salario_data_scientists, color = 'r', label = 'Data Scientists')
plt.plot(experiencia,Salario_ing_Software, color = 'g', label = 'Ing Software')
plt.title('Salarios')
plt.xlabel('Experiencia')
plt.ylabel('Ganacias')
plt.legend(['Data Scientis', 'Ing en Software'])
plt.show
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(experiencia,Salario_data_scientists, color = '#0f0f0f', label = 'Data Scientists',linestyle = '--')
plt.plot(experiencia,Salario_ing_Software, color = 'g', label = 'Ing Software',linestyle = ':')
plt.title('Salarios')
plt.xlabel('Experiencia')
plt.ylabel('Ganacias')
plt.legend(['Data Scientis', 'Ing en Software'])
plt.show
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(experiencia,Salario_data_scientists, color = '#0f0f0f', label = 'Data Scientists',linestyle = '--', marker = 'o')
plt.plot(experiencia,Salario_ing_Software, color = 'g', label = 'Ing Software',linestyle = ':', marker = '*')
plt.title('Salarios')
plt.xlabel('Experiencia')
plt.ylabel('Ganacias')
plt.legend(['Data Scientis', 'Ing en Software'])
plt.legend()
plt.grid(color = 'r',linestyle = '-', linewidth = 2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = ['A','B','C','D']
y = [3,8,1,10]
tendencia = [3,8,1,10]
plt.bar(x,y)
plt.plot(x,tendencia,color = 'r')
plt.title('salarios')
plt.xlabel('Experiencia')
plt.ylabel('Ganancias')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# %pip install numpy

# %%
import numpy as np

# %%
x = np.random.rand(100)
y = np.random.rand(100)

# %%
plt.scatter(x,y)
plt.title('Gráfico de dispersión')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
datos = np.random.randn(10000)
plt.hist(datos,bins=30)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.show()

# %%
datos = [np.random.normal(0,std,100) for std in range(1,4)]
plt.boxplot(datos, vert = True)
plt.show()

# %%
import pandas as pd
import numpy as np

# %%
data_range = pd.date_range(start = '2023-01-01', end = '2023-12-31', freq ='D')
precios = np.cumsum(np.random.randn(len(data_range))) + 100

# %%
data = pd.DataFrame({'Date':data_range, 'Precios':precios})
data.head()
# Out:
#         Date     Precios
# 0 2023-01-01   99.935577
# 1 2023-01-02   99.892867
# 2 2023-01-03  100.782610
# 3 2023-01-04  100.601993
# 4 2023-01-05  101.456195

# %%
plt.plot(data['Date'], data['Precios'], label = 'Precios')
plt.show()

# %%
x = np.linspace(0,10,100)
y1 = np.sin(x)

# %%
fig, axs = plt.subplots(2,2, figsize = (15,10))

axs[0,0].plot(x,y1)
axs[0,0].set_title('Gráfico de líneas')
axs[0,0].grid(True)


axs[0,1].bar(categorias,valores)
axs[0,1].set_title('Gráfico de barras')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 8
#       4 axs[0,0].set_title('Gráfico de líneas')
#       5 axs[0,0].grid(True)
# ----> 8 axs[0,1].bar(categorias,valores)
#       9 axs[0,1].set_title('Gráfico de barras')
#      11 plt.show()
#
# NameError: name 'categorias' is not defined
