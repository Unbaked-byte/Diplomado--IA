# %% [markdown]
# Analisis exploratorio de datos tabulados

# %%
import pandas as pd 
pd.set_option('display.max_columns', None)

# %%
# Lectura de Datos 

df = pd.read_csv('Human_Resources.csv')
df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49            NaN        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(2)
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 1   49            NaN        No  Travel_Frequently        279
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
#
#    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0              1             1.0                        2  Female          94
# 1              1             2.0                        3    Male          61
#
#    JobInvolvement  JobLevel             JobRole  JobSatisfaction  \
# 0               3         2     Sales Executive                4
# 1               2         2  Research Scientist                2
#
#   MaritalStatus  MonthlyRate  NumCompaniesWorked Over18 OverTime  \
# ...

# %%
df.head(3)
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
#
#    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0              1             1.0                        2  Female          94
# 1              1             2.0                        3    Male          61
# 2              1             4.0                        4    Male          92
#
#    JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   MonthlyIncome             1467 non-null   float64
#  2   Attrition                 1470 non-null   object
#  3   BusinessTravel            1470 non-null   object
#  4   DailyRate                 1470 non-null   int64
#  5   Department                1469 non-null   object
#  6   DistanceFromHome          1470 non-null   int64
#  7   Education                 1470 non-null   int64
#  8   EducationField            1469 non-null   object
#  9   EmployeeCount             1470 non-null   int64
#  10  EmployeeNumber            1469 non-null   float64
#  11  EnvironmentSatisfaction   1470 non-null   int64
#  12  Gender                    1469 non-null   object
# ...

# %%
df['Department'].unique() #Identificación de valores Únicos
# Out:
# array(['Sales', 'Research & Development', nan, 'Human Resources'],
#       dtype=object)

# %%
df['Age'].unique() #Identificación de valores Únicos
# Out:
# array([41, 49, 37, 33, 27, 32, 59, 30, 38, 36, 35, 29, 31, 34, 28, 22, 53,
#        24, 21, 42, 44, 46, 39, 43, 50, 26, 48, 55, 45, 56, 23, 51, 40, 54,
#        58, 20, 25, 19, 57, 52, 47, 18, 60], dtype=int64)

# %%
df.nunique()
# Out:
# Age                           43
# MonthlyIncome               1346
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1469
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyRate                 1425
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %%
df.columns.to_list() # Me genera una lista de los nombres de las columnas en la tabla
# Out:
# ['Age',
#  'MonthlyIncome',
#  'Attrition',
#  'BusinessTravel',
#  'DailyRate',
#  'Department',
#  'DistanceFromHome',
#  'Education',
#  'EducationField',
#  'EmployeeCount',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'Gender',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobRole',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'Over18',
#  'OverTime',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
for name in df.columns.to_list(): 
    print(f'La columna: {name} contiene los elementos {df[name].unique()}')
# Out:
# La columna: Age contiene los elementos [41 49 37 33 27 32 59 30 38 36 35 29 31 34 28 22 53 24 21 42 44 46 39 43
#  50 26 48 55 45 56 23 51 40 54 58 20 25 19 57 52 47 18 60]
# La columna: MonthlyIncome contiene los elementos [5993.   nan 2090. ... 9991. 5390. 4404.]
# La columna: Attrition contiene los elementos ['Yes' 'No']
# La columna: BusinessTravel contiene los elementos ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# La columna: DailyRate contiene los elementos [1102  279 1373 1392  591 1005 1324 1358  216 1299  809  153  670 1346
#   103 1389  334 1123 1219  371  673 1218  419  391  699 1282 1125  691
#   477  705  924 1459  125  895  813 1273  869  890  852 1141  464 1240
#  1357  994  721 1360 1065  408 1211 1229  626 1434 1488 1097 1443  515
#   853 1142  655 1115  427  653  989 1435 1223  836 1195 1339  664  318
#  1225 1328 1082  548  132  746  776  193  397  945 1214  111  573 1153
#  1400  541  432  288  669  530  632 1334  638 1093 1217 1353  120  682
# ...

# %%
# Eliminar columnas que no brindan información 
valores_unicos_n = df.nunique()

columnas_sn_info = valores_unicos_n[valores_unicos_n == 1].index
columnas_sn_info
# Out:
# Index(['EmployeeCount', 'Over18', 'StandardHours'], dtype='object')

# %%
df_clean = df.drop(columnas_sn_info, axis=1)

# %%
# df.drop(columnas_sn_info, axis = 1, inplace = True) Elimina del dataframe original

# %%
df.head(3)
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
#
#    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0              1             1.0                        2  Female          94
# 1              1             2.0                        3    Male          61
# 2              1             4.0                        4    Male          92
#
#    JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# ...

# %%
df_clean = df.drop(columnas_sn_info, axis = 1)

# %%
# df_clean2 = df_clean.drop('DailyRate', axis=1)

# %%
df_clean.head(3)
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
#
#    EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0             1.0                        2  Female          94
# 1             2.0                        3    Male          61
# 2             4.0                        4    Male          92
#
#    JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# 0               3         2        Sales Executive                4
# ...

# %%
df_clean.describe()
# Out:
#                Age  MonthlyIncome    DailyRate  DistanceFromHome    Education  \
# count  1470.000000    1467.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810    6505.155419   802.485714          9.192517     2.912925
# std       9.135373    4711.297846   403.509100          8.106864     1.024165
# min      18.000000    1009.000000   102.000000          1.000000     1.000000
# 25%      30.000000    2911.000000   465.000000          2.000000     2.000000
# 50%      36.000000    4908.000000   802.000000          7.000000     3.000000
# 75%      43.000000    8378.000000  1157.000000         14.000000     4.000000
# max      60.000000   19999.000000  1499.000000         29.000000     5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1469.000000              1470.000000  1470.000000     1470.000000
# mean      1025.556161                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# Division de un dataset

# %%
siguen_trbajando = df_clean[df_clean['Attrition'] == 'No']
renunciaron = df_clean[df_clean['Attrition'] == 'Yes']

# %%
df_clean.describe()
# Out:
#                Age  MonthlyIncome    DailyRate  DistanceFromHome    Education  \
# count  1470.000000    1467.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810    6505.155419   802.485714          9.192517     2.912925
# std       9.135373    4711.297846   403.509100          8.106864     1.024165
# min      18.000000    1009.000000   102.000000          1.000000     1.000000
# 25%      30.000000    2911.000000   465.000000          2.000000     2.000000
# 50%      36.000000    4908.000000   802.000000          7.000000     3.000000
# 75%      43.000000    8378.000000  1157.000000         14.000000     4.000000
# max      60.000000   19999.000000  1499.000000         29.000000     5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1469.000000              1470.000000  1470.000000     1470.000000
# mean      1025.556161                 2.721769    65.891156        2.729932
# ...

# %%
renunciaron.describe()
# Out:
#               Age  MonthlyIncome    DailyRate  DistanceFromHome   Education  \
# count  237.000000     236.000000   237.000000        237.000000  237.000000
# mean    33.607595    4771.588983   750.362869         10.632911    2.839662
# std      9.689350    3640.097444   401.899519          8.452525    1.008244
# min     18.000000    1009.000000   103.000000          1.000000    1.000000
# 25%     28.000000    2371.500000   408.000000          3.000000    2.000000
# 50%     32.000000    3187.000000   699.000000          9.000000    3.000000
# 75%     39.000000    5850.000000  1092.000000         17.000000    4.000000
# max     58.000000   19859.000000  1496.000000         29.000000    5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count      237.000000               237.000000  237.000000      237.000000
# mean      1010.345992                 2.464135   65.573840        2.518987
# ...

# %%
siguen_trbajando.describe()
# Out:
#                Age  MonthlyIncome    DailyRate  DistanceFromHome    Education  \
# count  1233.000000    1231.000000  1233.000000       1233.000000  1233.000000
# mean     37.561233    6837.504468   812.504461          8.915653     2.927007
# std       8.888360    4820.415800   403.208379          8.012633     1.027002
# min      18.000000    1051.000000   102.000000          1.000000     1.000000
# 25%      31.000000    3211.500000   477.000000          2.000000     2.000000
# 50%      36.000000    5206.000000   817.000000          7.000000     3.000000
# 75%      43.000000    8835.500000  1176.000000         13.000000     4.000000
# max      60.000000   19999.000000  1499.000000         29.000000     5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1232.000000              1233.000000  1233.000000     1233.000000
# mean      1028.482143                 2.771290    65.952149        2.770479
# ...

# %%
personas_sueldo_bien = siguen_trbajando[(siguen_trbajando['MonthlyIncome'] > 10000) & (siguen_trbajando['MonthlyIncome'] < 15000)]

# %%
personas_sueldo_bien.describe()
# Out:
#               Age  MonthlyIncome    DailyRate  DistanceFromHome   Education  \
# count  128.000000     128.000000   128.000000        128.000000  128.000000
# mean    44.132812   12018.539062   796.640625         10.070312    2.968750
# std      8.368831    1442.897538   404.609323          8.707119    1.011256
# min     27.000000   10096.000000   102.000000          1.000000    1.000000
# 25%     38.000000   10685.750000   474.250000          3.000000    2.000000
# 50%     44.000000   11774.500000   798.500000          7.000000    3.000000
# 75%     51.000000   13459.500000  1104.500000         17.000000    4.000000
# max     60.000000   14852.000000  1499.000000         29.000000    5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count      128.000000               128.000000  128.000000      128.000000
# mean       974.875000                 2.703125   66.476562        2.648438
# ...

# %%
personas_sueldo_bien = siguen_trbajando[(siguen_trbajando['MonthlyIncome'] > 10000) & (siguen_trbajando['DistanceFromHome'] > 8) & (siguen_trbajando['EnvironmentSatisfaction'] == 4)]

# %%
personas_sueldo_bien.describe()
# Out:
#              Age  MonthlyIncome    DailyRate  DistanceFromHome  Education  \
# count  31.000000      31.000000    31.000000         31.000000  31.000000
# mean   47.096774   15489.096774   850.935484         18.064516   3.032258
# std     6.759462    3221.786134   450.191066          7.252289   0.706346
# min    33.000000   10496.000000   102.000000          9.000000   2.000000
# 25%    43.500000   13258.000000   606.000000         10.000000   3.000000
# 50%    48.000000   16328.000000   939.000000         18.000000   3.000000
# 75%    51.000000   17762.500000  1229.000000         24.500000   3.000000
# max    59.000000   19847.000000  1450.000000         28.000000   5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count       31.000000                     31.0   31.000000       31.000000
# mean      1151.193548                      4.0   68.612903        2.774194
# std        532.564889                      0.0   20.668297        0.616964
# ...

# %%
personas_sueldo_bien.head()
# Out:
#      Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 98    58        13872.0        No      Travel_Rarely        682
# 112   54        17328.0        No         Non-Travel        142
# 147   41        17181.0        No  Travel_Frequently        857
# 235   43        16064.0        No      Travel_Rarely       1034
# 367   50        10496.0        No      Travel_Rarely       1046
#
#                  Department  DistanceFromHome  Education    EducationField  \
# 98                    Sales                10          4           Medical
# 112         Human Resources                26          3   Human Resources
# 147  Research & Development                10          3     Life Sciences
# 235                   Sales                16          3         Marketing
# 367  Research & Development                10          3  Technical Degree
#
#      EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# ...

# %%
personas_sueldo_bien['JobRole'].unique()
# Out:
# array(['Sales Executive', 'Manager', 'Healthcare Representative',
#        'Research Director', 'Manufacturing Director'], dtype=object)

# %%
personas_sueldo_bien[personas_sueldo_bien['JobRole'] == 'Manager'].describe()
# Out:
#              Age  MonthlyIncome    DailyRate  DistanceFromHome  Education  \
# count  11.000000      11.000000    11.000000         11.000000  11.000000
# mean   45.545455   18115.000000   662.545455         16.000000   2.909091
# std     7.104416    1290.906891   446.154987          6.855655   0.539360
# min    33.000000   16064.000000   105.000000          9.000000   2.000000
# 25%    41.500000   17254.500000   189.500000          9.500000   3.000000
# 50%    45.000000   17650.000000   722.000000         16.000000   3.000000
# 75%    49.500000   19522.000000  1046.500000         21.500000   3.000000
# max    58.000000   19847.000000  1234.000000         26.000000   4.000000
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count       11.000000                     11.0   11.000000       11.000000
# mean      1188.454545                      4.0   74.545455        2.909091
# std        706.424711                      0.0   22.927554        0.539360
# ...

# %% [markdown]
# # Tratamiento de Datos Faltantes

# %%
# Contamos cuantos valores nulos tenemos por cada variable 
valores_nulos = df_clean.isnull().sum()
valores_nulos
# Out:
# Age                         0
# MonthlyIncome               3
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  1
# DistanceFromHome            0
# Education                   0
# EducationField              1
# EmployeeNumber              1
# EnvironmentSatisfaction     0
# Gender                      1
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     1
# JobSatisfaction             0
# MaritalStatus               1
# MonthlyRate                 2
# NumCompaniesWorked          0
# OverTime                    0
# PercentSalaryHike           1
# PerformanceRating           1
# RelationshipSatisfaction    0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# ...

# %%
len(df_clean) # Número de filas
# Out:
# 1470

# %%
df_clean.shape # Número de filas y columnas
# Out:
# (1470, 32)

# %%
porcentaje = (valores_nulos / len(df_clean)) * 100 # Porcentaje de valores nulos
porcentaje
# Out:
# Age                         0.000000
# MonthlyIncome               0.204082
# Attrition                   0.000000
# BusinessTravel              0.000000
# DailyRate                   0.000000
# Department                  0.068027
# DistanceFromHome            0.000000
# Education                   0.000000
# EducationField              0.068027
# EmployeeNumber              0.068027
# EnvironmentSatisfaction     0.000000
# Gender                      0.068027
# HourlyRate                  0.000000
# JobInvolvement              0.000000
# JobLevel                    0.000000
# JobRole                     0.068027
# JobSatisfaction             0.000000
# MaritalStatus               0.068027
# MonthlyRate                 0.136054
# NumCompaniesWorked          0.000000
# OverTime                    0.000000
# PercentSalaryHike           0.068027
# PerformanceRating           0.068027
# RelationshipSatisfaction    0.000000
# StockOptionLevel            0.000000
# ...

# %%
#df_clean_sn_na = df_clean.dropna(axis=0) # Elimina las filas con valores nulos

# %%
#len(df_clean_sn_na)

# %%
#df_clean_sn_na.isnull().sum() # Ya no hay filas on valores nulos

# %%
# %pip install -U scikit-learn
# Out:
# ...
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB 682.7 kB/s eta 0:00:17
#    ---------------------------------------- 0.0/11.0 MB 495.5 kB/s eta 0:00:23
#    ---------------------------------------- 0.1/11.0 MB 939.4 kB/s eta 0:00:12
#     --------------------------------------- 0.2/11.0 MB 1.3 MB/s eta 0:00:09
#    - -------------------------------------- 0.3/11.0 MB 1.5 MB/s eta 0:00:08
#    - -------------------------------------- 0.5/11.0 MB 1.9 MB/s eta 0:00:06
#    --- ------------------------------------ 1.0/11.0 MB 3.4 MB/s eta 0:00:03
#    ------- -------------------------------- 2.1/11.0 MB 5.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.3/11.0 MB 8.1 MB/s eta 0:00:01
# ...

# %%
from sklearn.impute import SimpleImputer
from sklearn.impute import KNNImputer


impute_numeric = SimpleImputer(strategy = 'mean')

mpute_numeric = SimpleImputer(strategy = 'mean')

numeric_columns = df_clean.select_dtypes(include = ['number'] ).columns
numeric_columns
# Out:
# Index(['Age', 'MonthlyIncome', 'DailyRate', 'DistanceFromHome', 'Education',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyRate',
#        'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df_clean[numeric_columns] = impute_numeric.fit_transform(df_clean[numeric_columns])

# %%
impute_categorico = SimpleImputer(strategy = 'most_frequent')

categorical_columns = df_clean.select_dtypes(include = ['number'] ).columns
numeric_columns

df_clean[categorical_columns] = impute_categorico.fit_transform(df_clean[numeric_columns])

# %%
df_clean.isnull().sum()
# Out:
# Age                         0
# MonthlyIncome               0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  1
# DistanceFromHome            0
# Education                   0
# EducationField              1
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      1
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     1
# JobSatisfaction             0
# MaritalStatus               1
# MonthlyRate                 0
# NumCompaniesWorked          0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# ...

# %% [markdown]
# # Tratar con Datos Nominales u Ordinales

# %%
for name in df_clean.columns.to_list():
    print(f'{name} : {df_clean[name].unique()}')
    print('\n')
# Out:
# Age : [41. 49. 37. 33. 27. 32. 59. 30. 38. 36. 35. 29. 31. 34. 28. 22. 53. 24.
#  21. 42. 44. 46. 39. 43. 50. 26. 48. 55. 45. 56. 23. 51. 40. 54. 58. 20.
#  25. 19. 57. 52. 47. 18. 60.]
#
#
# MonthlyIncome : [5993.         6505.15541922 2090.         ... 9991.         5390.
#  4404.        ]
#
#
# Attrition : ['Yes' 'No']
#
#
# BusinessTravel : ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
#
#
# DailyRate : [1102.  279. 1373. 1392.  591. 1005. 1324. 1358.  216. 1299.  809.  153.
#   670. 1346.  103. 1389.  334. 1123. 1219.  371.  673. 1218.  419.  391.
#   699. 1282. 1125.  691.  477.  705.  924. 1459.  125.  895.  813. 1273.
#   869.  890.  852. 1141.  464. 1240. 1357.  994.  721. 1360. 1065.  408.
#  1211. 1229.  626. 1434. 1488. 1097. 1443.  515.  853. 1142.  655. 1115.
#   427.  653.  989. 1435. 1223.  836. 1195. 1339.  664.  318. 1225. 1328.
#  1082.  548.  132.  746.  776.  193.  397.  945. 1214.  111.  573. 1153.
# ...

# %%
#def attrition(s): 
#   if s == 'Yes' : 
#       return 1
#   else:
#       return 0

# df_clean['Attrition'] = df_clean['Attrition'].apply(Attitrion_labes1)

#df_clean['Attrition'] = df_clean['Attrition'].apply(lambda s: 1 if s == 'Yes' else 0)

# %%
# Variables Ordinales
Attitrion_labes1 = {'Yes':1,'No':0}

df_clean['Attrition'] = df_clean['Attrition'].map(Attitrion_labes1)

# %%
# Avriables Nominales
df_clean = pd.get_dummies(df_clean, columns= ['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'OverTime'])

# %%
df_clean
# Out:
#        Age  MonthlyIncome  Attrition  DailyRate  DistanceFromHome  Education  \
# 0     41.0    5993.000000          1     1102.0               1.0        2.0
# 1     49.0    6505.155419          0      279.0               8.0        1.0
# 2     37.0    2090.000000          1     1373.0               2.0        2.0
# 3     33.0    2909.000000          0     1392.0               3.0        4.0
# 4     27.0    3468.000000          0      591.0               2.0        1.0
# ...    ...            ...        ...        ...               ...        ...
# 1465  36.0    2571.000000          0      884.0              23.0        2.0
# 1466  39.0    9991.000000          0      613.0               6.0        1.0
# 1467  27.0    6142.000000          0      155.0               4.0        3.0
# 1468  49.0    5390.000000          0     1023.0               2.0        3.0
# 1469  34.0    4404.000000          0      628.0               8.0        3.0
#
# ...

# %%
df_clean.describe()
# Out:
#                Age  MonthlyIncome    Attrition    DailyRate  DistanceFromHome  \
# count  1470.000000    1470.000000  1470.000000  1470.000000       1470.000000
# mean     36.923810    6505.155419     0.161224   802.485714          9.192517
# std       9.135373    4706.484668     0.367863   403.509100          8.106864
# min      18.000000    1009.000000     0.000000   102.000000          1.000000
# 25%      30.000000    2914.750000     0.000000   465.000000          2.000000
# 50%      36.000000    4933.000000     0.000000   802.000000          7.000000
# 75%      43.000000    8368.500000     0.000000  1157.000000         14.000000
# max      60.000000   19999.000000     1.000000  1499.000000         29.000000
#
#          Education  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count  1470.000000     1470.000000              1470.000000  1470.000000
# mean      2.912925     1025.556161                 2.721769    65.891156
# ...

# %%
df_clean.to_csv('Preproced.csv', index=False)

# %% [markdown]
# # Detección de valores Atípicos

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## EJEMPLO

# %%
Q1 = df_clean['Age'].quantile(0.25)
Q3 = df_clean['Age'].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR
limite_inferior


limite_superior = Q1 + 1.5 * IQR
limite_superior
# Out:
# 49.5

# %%
df_test = df_clean.copy()

indices = np.random.choice(df_test.index, 2 , replace=False)

df_test.loc[indices[0],'Age'] += 3 * IQR
df_test.loc[indices[1],'Age'] += 3 * IQR

# %%
df_test.boxplot(column='Age')
# Out:
# <Axes: >

# %% [markdown]
# ## EJERCICIO 3

# %%
Q1 = df_clean['Age'].quantile(0.25)
Q3 = df_clean['Age'].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR
limite_inferior

print(limite_inferior)

limite_superior = Q1 + 1.5 * IQR
limite_superior

print(limite_superior)
# Out:
# 10.5
# 49.5

# %%
df_clean.boxplot(column= 'Age')
# Out:
# <Axes: >

# %%
Q1 = df_clean['Age'].quantile(0.25)
Q3 = df_clean['Age'].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR
limite_inferior

print(limite_inferior)

limite_superior = Q1 + 1.5 * IQR
limite_superior

print(limite_superior)
# Out:
# 10.5
# 49.5

# %%
# plt.hist(df_clean['Age'], bins=30)
#sns.distplot(x=df_clean['MonthlyIncome'])
#plt.show()

df_clean.hist(bins=30, figsize=(30,30))
plt.show()

# %%
from sklearn.ensemble import IsolationForest

# %%
forest = IsolationForest(contamination='auto').fit(df_clean[['Age','MonthlyIncome']])

# %%
forest.predict(df_clean[['Age','MonthlyIncome']])

# %%
forest = IsolationForest(contamination='auto').fit(df_clean[['Age']])

# %%
forest.predict([[80]])
# Out:
# c:\Users\xxunb\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# array([-1])

# %%
forest = IsolationForest(contamination='auto').fit(df_clean[['Age','MonthlyIncome', 'Movimiento']])

# %%
forest.predict([[50],[100000],[500000]])
# Out:
# c:\Users\xxunb\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# array([-1, -1, -1])

# %%
forest = IsolationForest(contamination='auto').fit(df_clean[['Age','MonthlyIncome']])
prediction = forest.predict(df_test[['Age','MonthlyIncome']])
prediction
# Out:
# array([ 1, -1,  1, ...,  1,  1,  1])

# %%
prediction.shape
# Out:
# (1470,)

# %%
df_clean.shape
# Out:
# (1470, 53)

# %%
import seaborn as sns

correlaciones = df_clean.corr()

f,ax = plt.subplots(figsize = (50,50))
sns.heatmap(correlaciones, annot=True)
plt.show()

# %%
sns.pairplot(df_clean, vars=['MonthlyIncome','Age'])
# Out:
# c:\Users\xxunb\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\xxunb\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.pairplot(df_clean, hue='Attrition',vars=['MonthlyIncome','Age'])
# Out:
# c:\Users\xxunb\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\xxunb\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.pairplot(df_clean, hue='Education',vars=['MonthlyIncome','Age'])
# Out:
# c:\Users\xxunb\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\xxunb\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.pairplot(df_clean, hue='Education',vars=['MonthlyIncome','YearsAtCompany'])
# Out:
# c:\Users\xxunb\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\xxunb\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df_clean[['MonthlyIncome','YearsAtCompany']].corr()
# Out:
#                 MonthlyIncome  YearsAtCompany
# MonthlyIncome        1.000000        0.513953
# YearsAtCompany       0.513953        1.000000

# %% [markdown]
# # Sub dividir mi datasheet

# %%
x = df_clean[[]]
y = df_clean[[]]
